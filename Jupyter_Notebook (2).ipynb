# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# Bold text:**Colson Richter**
# Supply Chain Engineer

# %% [markdown]
# Italic text: *I am interested in Data Science because of how rapidly the demand for data science professionals is growing the widespread application of data science tools/skills*

# %% [markdown]
# ### My code in the following cell is meant to make a simple calculation, namely an addition math function.

# %%
2 + 2

# %% [markdown]
# 1. I am going to add a picture
# 2. It is from Korea University
# ![Korea University]([APRM8994.JPG]/(attachment:4fe21051-f637-45c7-99c1-63490ffc0a84.JPG))
# ~~I miss Korea so much I cry about it soe
